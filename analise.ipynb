# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
dados = pd.read_csv("Dataset_Treino.csv")

# %%
dados.head()
# Out:
#    ID_Aluno  Idade  Tipo_escola                       Escolaridade Estado  \
# 0      1650     20       public  Cursando o 3º ano do Ensino Médio     SP
# 1       771     17       public  Cursando o 3º ano do Ensino Médio     SP
# 2       503     22       public  Cursando o 3º ano do Ensino Médio     RJ
# 3      1586     19       public  Cursando o 3º ano do Ensino Médio     SP
# 4      2381     17  scholarship  Cursando o 3º ano do Ensino Médio     SP
#
#          Municipio Trabalhando Estudando  \
# 0          Ubatuba         Não       Não
# 1        São Paulo         Não       Sim
# 2        Queimados         Sim       Não
# 3  Mogi das Cruzes         Não       Não
# 4        São Paulo         Não       Sim
#
#                            Concluiu_EAD  \
# 0   Nunca realizei um curso a distância
# 1   Nunca realizei um curso a distância
# 2   Nunca realizei um curso a distância
# 3  Sim e fiz totalmente pelo computador
# 4  Sim e fiz totalmente pelo computador
#
# ...

# %% [markdown]
# - Análise rápida inicial

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID_Aluno                 2500 non-null   int64
#  1   Idade                    2500 non-null   int64
#  2   Tipo_escola              2500 non-null   object
#  3   Escolaridade             2500 non-null   object
#  4   Estado                   2500 non-null   object
#  5   Municipio                2495 non-null   object
#  6   Trabalhando              2500 non-null   object
#  7   Estudando                2496 non-null   object
#  8   Concluiu_EAD             2500 non-null   object
#  9   Aprender_EAD             2500 non-null   object
#  10  Recursos                 2498 non-null   object
#  11  Disponibilidade_Tutoria  2500 non-null   object
#  12  Disponibilidade_3_Meses  2500 non-null   object
#  13  Pessoas_Casa             2500 non-null   object
# ...

# %% [markdown]
# ## Próximos passos

# %% [markdown]
# 1. mudar o tipo de dados da coluna Data_Inscrição de object para DateTime
# 2. Pré-processar os dados textos
# 3. Observar a existencia de dados ausentes
# 4. Feature importance
# 5. Correlação
# 6.
